# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
from mcp_server.weather_broker import (
    get_current_weather,
    get_forecast,
    get_weather_recommendation,
)

print(get_current_weather("Dallas, TX"))

# %%
print(get_forecast("Dallas, TX", 3))

# %%
print(
    get_weather_recommendation(
        "Dallas, TX",
        "2026-08-10",
    )
)

# %%
# %pip install sqlalchemy>=2.0.30 psycopg2-binary>=2.9.9

import mcp_server.lakebase as lakebase

print(
    lakebase.run_query("""
        SELECT table_name
        FROM information_schema.tables
        WHERE table_schema = 'public'
          AND table_name = 'weather_mcp_activity'
    """)
)

# %%
# %sh
databricks apps set-permissions mcp-server-weather --allow-instance-access
